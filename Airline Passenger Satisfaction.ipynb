# %% [markdown]
# ## Airline Passenger Satisfaction

# %% [markdown]
# ### Life cycle of Machine learning Project
# - Understanding the Problem Statement
# - Data Collection
# - Data Checks to perform
# - Exploratory data analysis
# - Data Pre-Processing
# - Model Training
# - Choose best model

# %% [markdown]
# ### 1) Problem statement
# - #### This project understands how the satisfaction level of the airline passengers are affected by the services and facilities provided by Airlines Company

# %% [markdown]
# ### 2) Data Collection
# - ##### Dataset Source - https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction
# - ##### The data consists of train set and test set with 103904 rows and 25976 rows in train and test sets whilst 25 columns in both the sets.

# %%
#! pip install opendatasets

# %%
#import opendatasets as opd

# %%
#opd.download('https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction?select=train.csv')

# %%
#opd.download('https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction?select=test.csv',force=Trus)

# %%
#import os
#os.listdir()

# %% [markdown]
# ### 2.1 Import Data and Required Packages
# - Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

pd.pandas.set_option('display.max_columns',None)

# %% [markdown]
# ##### Train Set

# %%
df_train=pd.read_csv('airline-passenger-satisfaction/train.csv')
df_train.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              1
# ...

# %% [markdown]
# ##### Test Set

# %%
df_test=pd.read_csv('airline-passenger-satisfaction/test.csv')
df_test.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  4                       3              4
# ...

# %%
df_train.shape, df_test.shape
# Out:
# ((103904, 25), (25976, 25))

# %% [markdown]
# ### 2.2 Dataset information
# - Gender: Gender of the passengers (Female, Male)
# - Customer Type: The customer type (Loyal customer, disloyal customer)
# - Age: The actual age of the passengers
# - Type of Travel: Purpose of the flight of the passengers (Personal Travel, Business Travel)
# - Class: Travel class in the plane of the passengers (Business, Eco, Eco Plus)
# - Flight distance: The flight distance of this journey
# - Inflight wifi service: Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
# - Departure/Arrival time convenient: Satisfaction level of Departure/Arrival time convenient
# - Ease of Online booking: Satisfaction level of online booking
# - Gate location: Satisfaction level of Gate location
# - Food and drink: Satisfaction level of Food and drink
# - Online boarding: Satisfaction level of online boarding
# - Seat comfort: Satisfaction level of Seat comfort
# - Inflight entertainment: Satisfaction level of inflight entertainment
# - On-board service: Satisfaction level of On-board service
# - Leg room service: Satisfaction level of Leg room service
# - Baggage handling: Satisfaction level of baggage handling
# - Check-in service: Satisfaction level of Check-in service
# - Inflight service: Satisfaction level of inflight service
# - Cleanliness: Satisfaction level of Cleanliness
# - Departure Delay in Minutes: Minutes delayed when departure
# - Arrival Delay in Minutes: Minutes delayed when Arrival
# - Satisfaction: Airline satisfaction level(Satisfaction, neutral or dissatisfaction)

# %% [markdown]
# ### 3. Data Checks to perform
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set
# - Check various categories present in the different categorical column

# %%
df_train.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
#mean=df_train['Arrival Delay in Minutes'].mean()
#df_train['Arrival Delay in Minutes'].fillna(mean,inplace=True)

# %%
#df_train.isnull().isnull().sum().any()

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df_train.nunique()
# Out:
# Unnamed: 0                           103904
# id                                   103904
# Gender                                    2
# Customer Type                             2
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        3802
# Inflight wifi service                     6
# Departure/Arrival time convenient         6
# Ease of Online booking                    6
# Gate location                             6
# Food and drink                            6
# Online boarding                           6
# Seat comfort                              6
# Inflight entertainment                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                          5
# Checkin service                           6
# Inflight service                          6
# ...

# %%
df_train.drop(['Unnamed: 0','id'],axis=1,inplace=True)
df_test.drop(['Unnamed: 0','id'],axis=1,inplace=True)

# %%
df_train.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean       39.379706      1189.448375               2.729683
# std        15.114964       997.147281               1.327829
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       843.000000               3.000000
# 75%        51.000000      1743.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %%
num_features=[feature for feature in df_train.columns if df_train[feature].dtype!='O']
cat_features=[feature for feature in df_train.columns if df_train[feature].dtype=='O']

print("numerical features : {}".format(num_features))
print('\n')
print("categorical features : {}".format(cat_features))
# Out:
# numerical features : ['Age', 'Flight Distance', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']
#
#
# categorical features : ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

# %% [markdown]
# ### Exploring Categorical Features

# %%
print("Categories in Gender : ",df_train['Gender'].unique())
print("Categories in Customer Type : ",df_train['Customer Type'].unique())
print("Categories in Type of Travel : ",df_train['Type of Travel'].unique())
print("Categories in Class : ",df_train['Class'].unique())
print("Categories in satisfaction : ",df_train['satisfaction'].unique())
# Out:
# Categories in Gender :  ['Male' 'Female']
# Categories in Customer Type :  ['Loyal Customer' 'disloyal Customer']
# Categories in Type of Travel :  ['Personal Travel' 'Business travel']
# Categories in Class :  ['Eco Plus' 'Business' 'Eco']
# Categories in satisfaction :  ['neutral or dissatisfied' 'satisfied']

# %%
df_train['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
df_train.groupby(['satisfaction', 'Gender']).size().unstack()
# Out:
# Gender                   Female   Male
# satisfaction
# neutral or dissatisfied   30193  28686
# satisfied                 22534  22491

# %% [markdown]
# ### Multivariate analysis using pieplot

# %%
plt.rcParams['figure.figsize'] = (40, 12)

plt.subplot(1, 5, 1)
size = df_train['Gender'].value_counts()
labels = 'Female','Male'
color = ['red','green']

plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 2)
size = df_train['Customer Type'].value_counts()
labels = 'Loyal Customer','disloyal Customer'
color = ['red','green']

plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Customer Type', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 3)
size = df_train['Type of Travel'].value_counts()
labels = 'Business travel','Personal Travel'
color = ['red','green']

plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Type of Travel', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 4)
size = df_train['Class'].value_counts()
labels = 'Business','Eco','Eco Plus'
color = ['red','green','blue']

plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Class ', fontsize = 20)
plt.axis('off')

plt.subplot(1, 5, 5)
size = df_train['satisfaction'].value_counts()
labels = 'neutral or dissatisfied','satisfied'
color = ['red','green']

plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('satisfaction ', fontsize = 20)
plt.axis('off')

plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# ##### Insights
# - Number of female airline passengers are more than males
# - There are more than 80% loyal passengers travelling through the airline
# - Approximately one-third of the passengers chose Business type of travel
# - Number of passengers travelling in Business class are much more higher than Economy or Economy plus class
# - Percentage of dissatisfied or neutral passengers are greater i.e., 57 % (this should get improved)

# %% [markdown]
# ### Feature Wise Visualization

# %%
df_train['Inflight wifi service'].value_counts()
# Out:
# Inflight wifi service
# 3    25868
# 2    25830
# 4    19794
# 1    17840
# 5    11469
# 0     3103
# Name: count, dtype: int64

# %% [markdown]
# #### GENDER COLUMN
# - How is distribution of Gender ?
# - Does gender has any impact on passenger satisfaction ?

# %% [markdown]
# #### UNIVARIATE ANALYSIS ( How is distribution of Gender ? )

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.countplot(x=df_train['Gender'],data=df_train,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df_train['Gender'].value_counts(),labels=['Female','Male'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()

# %% [markdown]
# - Female passengers seems to travel more than the males through Airline

# %% [markdown]
# #### UNIVARIATE ANALYSIS ( How is distribution of Customer Type ? )

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.countplot(x=df_train['Customer Type'],data=df_train,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df_train['Customer Type'].value_counts(),labels=['Loyal Customer','disloyal Customer'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()

# %% [markdown]
# - Number os Loyal Passengers to the airline are more than 80%

# %% [markdown]
# #### UNIVARIATE ANALYSIS ( How is distribution of Type of Travel ? )

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.countplot(x=df_train['Type of Travel'],data=df_train,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df_train['Type of Travel'].value_counts(),labels=['Business travel','Personal Travel'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['blue','orange'])
plt.show()

# %% [markdown]
# - Passengers travelling for Business purpose are higher than the personal

# %% [markdown]
# #### UNIVARIATE ANALYSIS ( How is distribution of Class ? )

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df_train['Class'],data=df_train,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df_train['Class'].value_counts(),labels=['Business','Eco','Eco Plus'],explode=[0,0.1,0.2],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000','pink'])
plt.show()

# %% [markdown]
# - Passengers travelling in Business class is highest

# %% [markdown]
# #### UNIVARIATE ANALYSIS ( How is distribution of satisfaction ? )

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df_train['satisfaction'],data=df_train,palette ='bright',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=20)
    
plt.pie(x=df_train['satisfaction'].value_counts(),labels=['neutral or dissatisfied','satisfied'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()

# %% [markdown]
# - Passengers are either sissatisfied or neutral with the Airline

# %% [markdown]
# #### BIVARIATE ANALYSIS ('Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction')

# %%
for col in cat_features:
    fig, ax = plt.subplots()
    counts = df_train.groupby(['satisfaction', col]).size().unstack()
    counts.plot(kind='bar', ax=ax)
    ax.set_xlabel('satisfaction')
    ax.set_ylabel('Count')
    ax.set_title(f'Bar plot of {col} by satisfaction')
    plt.show()

# %% [markdown]
# ##### Insights
# - Number of unsatisfied or neutral males and females are greater than satisfied
# - Number of unsatisfied or neutral and satisfied passengers, both are much higher for loyal passenger
# - Number of satisfied passenger are much higher who chose Business Travel
# - Number of people travelling in economy class who are unsatisfied are very high whilst passenger of Business class are satisfied with great number
# - Passengers dissatisfied or neutral with the airline facilities are greater than the satisfied passengers

# %%
plt.figure(figsize=(20,10))
for i in enumerate(['Customer Type', 'Type of Travel', 'Class', 'satisfaction']):
    plt.subplot(2,2,i[0]+1)
    sns.countplot(data=df_train,x=i[1],hue='Gender')
    plt.title(i[1])

# %% [markdown]
# ##### Insight
# - Both male and female genders are mostly loyal customers  and the type of travel they prefer is Business travel
# - Bothe genders mostly travels in Business Class followed by Eco class
# - Both the genders seems to be neutral or dissatisfied with the airline

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df_train,x='satisfaction',hue='Customer Type')
plt.subplot(142)
sns.histplot(data=df_train[df_train.Gender=='Female'],x='satisfaction',hue='Customer Type')
plt.title('Male')
plt.subplot(143)
sns.histplot(data=df_train[df_train.Gender=='Male'],x='satisfaction',hue='Customer Type')
plt.title('Female')
plt.show()

# %% [markdown]
# ##### Insight
# - The number of Loyal Customers dissatisfied with the airlines are higher in both genders

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df_train,x='satisfaction',hue='Type of Travel')
plt.subplot(142)
sns.histplot(data=df_train[df_train.Gender=='Female'],x='satisfaction',hue='Type of Travel')
plt.title('Male')
plt.subplot(143)
sns.histplot(data=df_train[df_train.Gender=='Male'],x='satisfaction',hue='Type of Travel')
plt.title('Female')
plt.show()

# %% [markdown]
# ##### Insight
# - The number Customers travelling for business are very much satisfied in both the genders

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df_train,x='satisfaction',hue='Class')
plt.subplot(142)
sns.histplot(data=df_train[df_train.Gender=='Female'],x='satisfaction',hue='Class')
plt.title('Male')
plt.subplot(143)
sns.histplot(data=df_train[df_train.Gender=='Male'],x='satisfaction',hue='Class')
plt.title('Female')
plt.show()

# %% [markdown]
# ### Exploring Numerical Features

# %%
df_train.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# ...

# %%
plt.subplot(111)
sns.countplot(data=df_train,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ##### Insight
# - Passengers of varying ages from 7 to 83 are seen travelling through this airline but passengers between 20 to 60 are travelling frequently

# %%
plot_num_features=['Inflight wifi service',
 'Departure/Arrival time convenient',
 'Ease of Online booking',
 'Gate location',
 'Food and drink',
 'Online boarding',
 'Seat comfort',
 'Inflight entertainment',
 'On-board service',
 'Leg room service',
 'Baggage handling',
 'Checkin service',
 'Inflight service',
 'Cleanliness']

# %%
list(enumerate(plot_num_features))
# Out:
# [(0, 'Inflight wifi service'),
#  (1, 'Departure/Arrival time convenient'),
#  (2, 'Ease of Online booking'),
#  (3, 'Gate location'),
#  (4, 'Food and drink'),
#  (5, 'Online boarding'),
#  (6, 'Seat comfort'),
#  (7, 'Inflight entertainment'),
#  (8, 'On-board service'),
#  (9, 'Leg room service'),
#  (10, 'Baggage handling'),
#  (11, 'Checkin service'),
#  (12, 'Inflight service'),
#  (13, 'Cleanliness')]

# %%
plt.figure(figsize=(20,30))
for i in enumerate(plot_num_features):
    plt.subplot(5,3,i[0]+1)
    sns.countplot(data=df_train,x=i[1])
    plt.title(i[1])

# %% [markdown]
# ##### Insight
# - Passengers seem not satisfied with Inflight wifi service and Ease of online booking as the ratings are mostly 2 and 3 whilst Departure/Arrival time convenient was rated 4 out of 5.
# - Passengers rated 3 for Gate Location and 4 are higher for both Food and drink,Online boarding.
# - Passengers rated 4 out of 5 for Seat comfort, Inflight entertainment,and On-board service are the highest.
# - Passengers rated the highest in i.e., 4 out of 5 in Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness.

# %%
plt.figure(figsize=(20,30))
for i in enumerate(plot_num_features):
    plt.subplot(5,3,i[0]+1)
    sns.countplot(data=df_train,x=i[1],hue='Gender')
    plt.title(i[1])

# %% [markdown]
# ##### Insight
# - Proportions for male and female are almost near to each other rating the services offered by the airlines

# %%
plt.figure(figsize=(20,25))
for i in enumerate(plot_num_features):
    plt.subplot(5,3,i[0]+1)
    sns.countplot(data=df_train,x=i[1],hue='satisfaction')
    plt.title(i[1])

# %% [markdown]
# #### Insight
# - Passengers satisfied with the Airlines rated highest for the services like 'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Cleanliness'.
# - Passengers are mostly unsatisfied with the services like 'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service'.

# %%
df_train.head(2)
# Out:
#   Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0   Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1   Male  disloyal Customer   25  Business travel  Business              235
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# 1             1                       1                 1                 5
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# ...

# %% [markdown]
# ### Distribution of Departure Delay in Minutes over Arrival Delay in Minutes According to satisfaction

# %%
fig=sns.scatterplot(df_train,x='Departure Delay in Minutes',
               y='Arrival Delay in Minutes',
                    hue='satisfaction',
                   palette={'satisfied':'lightblue','neutral or dissatisfied':'#E44242'})
plt.title('Departure Delay in Minutes over Arrival Delay in Minutes According to satisfaction')
# Out:
# Text(0.5, 1.0, 'Departure Delay in Minutes over Arrival Delay in Minutes According to satisfaction')

# %%
# Replace the values in the 'satisfaction' column with numeric values
df_train=df_train.copy()
df_train['satisfaction'] = df_train['satisfaction'].replace(['neutral or dissatisfied', 'satisfied'], [0, 1])
df_test['satisfaction'] = df_test['satisfaction'].replace(['neutral or dissatisfied', 'satisfied'], [0, 1])

# %%
# Create a subset of the data containing a subset of columns
subset = df_train[["Inflight wifi service", 
                        "Departure/Arrival time convenient",
                        "Ease of Online booking",
                        "Gate location",
                        "Food and drink",
                        "Online boarding",
                        "Seat comfort",
                        "Inflight entertainment",
                        "On-board service",
                        "Leg room service",
                        "Baggage handling",
                        "Checkin service",
                        "Inflight service",
                        "Cleanliness",
                   'satisfaction']]

# Calculate the correlation matrix for this subset of columns
corr = subset.corr()

# %%
# Create a heatmap using seaborn
plt.figure(figsize=(8, 8))
sns.heatmap(corr, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ### Exploring Flight Distance

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 2, 1)
plt.title('Flight Distance')
sns.histplot(x='Flight Distance',data=df_train,color='red',linewidth=3,kde=True)
# Out:
# <Axes: title={'center': 'Flight Distance'}, xlabel='Flight Distance', ylabel='Count'>

# %%
df_train[['Flight Distance','Age']].describe()
# Out:
#        Flight Distance            Age
# count    103904.000000  103904.000000
# mean       1189.448375      39.379706
# std         997.147281      15.114964
# min          31.000000       7.000000
# 25%         414.000000      27.000000
# 50%         843.000000      40.000000
# 75%        1743.000000      51.000000
# max        4983.000000      85.000000

# %% [markdown]
# ##### Insight
# - Our minimum Flight Distance is 31km ////Maximum Flight Distance -->4983km
# - Only 25% of flights are more than 1743 km
# - 92% of our customers are Adults
# - Our Flight Distance distribution is similar to curve bell,but it has a "positive skew" which means our values are tend to be the left side of our distribution.

# %% [markdown]
# ### Model Training

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.impute import SimpleImputer
import warnings

# %%
df_train.head(3)
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# ...

# %%
df_test.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0  Female     Loyal Customer   52  Business travel       Eco              160
# 1  Female     Loyal Customer   36  Business travel  Business             2863
# 2    Male  disloyal Customer   20  Business travel       Eco              192
# 3    Male     Loyal Customer   44  Business travel  Business             3377
# 4  Female     Loyal Customer   49  Business travel       Eco             1182
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# ...

# %%
X_train = df_train.drop('satisfaction',axis=1)
X_test = df_test.drop('satisfaction',axis=1)
y_train = df_train['satisfaction']
y_test = df_test['satisfaction']

# %%
X_train.head(3)
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# ...

# %%
X_test.head(3)
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0  Female     Loyal Customer   52  Business travel       Eco              160
# 1  Female     Loyal Customer   36  Business travel  Business             2863
# 2    Male  disloyal Customer   20  Business travel       Eco              192
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              4               3                4
# 1                       3              1               5                4
# 2                       2              4               2                2
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# ...

# %%
y_train.head(3)
# Out:
# 0    0
# 1    0
# 2    1
# Name: satisfaction, dtype: int64

# %%
y_test.head(3)
# Out:
# 0    1
# 1    1
# 2    0
# Name: satisfaction, dtype: int64

# %%
# Create Column Transformer with 3 types of transformers
num_features = X_train.select_dtypes(exclude="object").columns
cat_features = X_train.select_dtypes(include="object").columns

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

numeric_transformer = StandardScaler()
oh_transformer = OneHotEncoder()

preprocessor = ColumnTransformer(
    [
        ("OneHotEncoder", oh_transformer, cat_features),
         ("StandardScaler", numeric_transformer, num_features),        
    ]
)

# %%
X_train =preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %% [markdown]
# ### Dealing with null values

# %%
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# %%
X_train_imputed.shape, X_test_imputed.shape
# Out:
# ((103904, 27), (25976, 27))

# %%
X_train_imputed
# Out:
# array([[ 0.        ,  1.        ,  1.        , ...,  1.30586973,
#          0.26639265,  0.0729052 ],
#        [ 0.        ,  1.        ,  0.        , ..., -1.74229153,
#         -0.36137482, -0.23718437],
#        [ 1.        ,  0.        ,  1.        , ...,  1.30586973,
#         -0.3875318 , -0.39222916],
#        ...,
#        [ 0.        ,  1.        ,  0.        , ...,  0.54382941,
#         -0.20443295, -0.03045799],
#        [ 1.        ,  0.        ,  0.        , ..., -1.74229153,
#         -0.3875318 , -0.39222916],
#        [ 0.        ,  1.        ,  1.        , ..., -1.74229153,
#         -0.3875318 , -0.39222916]])

# %%
X_train_imputed.shape,X_test_imputed.shape
# Out:
# ((103904, 27), (25976, 27))

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(), 
    "CatBoosting Regressor": CatBoostRegressor(verbose=False),
    "AdaBoost Regressor": AdaBoostRegressor()
}
model_list = []
r2_list =[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train_imputed, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train_imputed)
    y_test_pred = model.predict(X_test_imputed)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
     
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    
    print('='*35)
    print('\n')
# Out:
# Logistic Regression
# Model performance for Training set
# - Root Mean Squared Error: 0.3533
# - Mean Absolute Error: 0.1248
# - R2 Score: 0.4916
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.3584
# - Mean Absolute Error: 0.1285
# - R2 Score: 0.4784
# ...
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 0.4955
# - Mean Absolute Error: 0.4911
# - R2 Score: 0.0000
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.4963
# - Mean Absolute Error: 0.4919
# - R2 Score: -0.0001
# ...
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 0.3315
# - Mean Absolute Error: 0.2483
# - R2 Score: 0.5524
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 0.3330
# - Mean Absolute Error: 0.2490
# - R2 Score: 0.5497
# ...
#
#
# K-Neighbors Regressor
# Model performance for Training set
# ...

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ab501_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ab501_row1_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_ab501_row2_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_ab501_row3_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_ab501_row4_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_ab501_row5_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_ab501_row6_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_ab501_row7_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_ab501_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_ab501">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab501_level0_col0" class="col_heading level0 col0" >Model Name</th>
# ...

# %% [markdown]
# ## Conclusion
# #### Random Forest Regressor and Catboosting Regressor are the best performing models and predicts the satisfaction of the passenger of the Airline by more than 88 percent
